# %% [markdown]
# <a href="https://colab.research.google.com/github/IsagiYoichi640/Introduction-to-Pandas/blob/main/Introduction_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
exam_data={'Name':['Gojo','Subaru','Emilia',
                   'Ron','Sakuta','Mai','Hermoine',
                   'Harry','John','Malfoy'],
           'Score':[80,97,85,78,99,100,95,90,50,40],
           'Attempts':[4,1,2,3,5,6,7,8,9,10],
           'Qualification':['yes','yes','yes','no','yes','yes',
                            'yes','yes','no','no']}
print(exam_data)
# Out:
# {'Name': ['Gojo', 'Subaru', 'Emilia', 'Ron', 'Sakuta', 'Mai', 'Hermoine', 'Harry', 'John', 'Malfoy'], 'Score': [80, 97, 85, 78, 99, 100, 95, 90, 50, 40], 'Attempts': [4, 1, 2, 3, 5, 6, 7, 8, 9, 10], 'Qualification': ['yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no']}

# %%
#create dataframe
df=pd.DataFrame(exam_data)
print(df)
# Out:
#        Name  Score  Attempts Qualification
# 0      Gojo     80         4           yes
# 1    Subaru     97         1           yes
# 2    Emilia     85         2           yes
# 3       Ron     78         3            no
# 4    Sakuta     99         5           yes
# 5       Mai    100         6           yes
# 6  Hermoine     95         7           yes
# 7     Harry     90         8           yes
# 8      John     50         9            no
# 9    Malfoy     40        10            no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           10 non-null     object
#  1   Score          10 non-null     int64
#  2   Attempts       10 non-null     int64
#  3   Qualification  10 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.head()
# Out:
#      Name  Score  Attempts Qualification
# 0    Gojo     80         4           yes
# 1  Subaru     97         1           yes
# 2  Emilia     85         2           yes
# 3     Ron     78         3            no
# 4  Sakuta     99         5           yes

# %%
df.isnull().sum()
# Out:
# Name             0
# Score            0
# Attempts         0
# Qualification    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Score', 'Attempts', 'Qualification'], dtype='object')

# %%
df.describe()
# Out:
#             Score  Attempts
# count   10.000000  10.00000
# mean    81.400000   5.50000
# std     20.774985   3.02765
# min     40.000000   1.00000
# 25%     78.500000   3.25000
# 50%     87.500000   5.50000
# 75%     96.500000   7.75000
# max    100.000000  10.00000
